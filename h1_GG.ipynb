# %% [markdown]
# # Generalized Extreme Value (GEV) Distribution Cumulative Distribution Function (CDF)
#
# The cumulative distribution function (CDF) of the Generalized Extreme Value (GEV) distribution is given by:
#
# $$
# F(x | \xi, \mu, \sigma) = \exp \left( - \left( 1 + \xi \frac{x - \mu}{\sigma} \right)^{-1/\xi} \right)
# $$
#
# Where:
# - $\xi$ is the shape parameter,
# - $\mu$ is the location parameter,
# - $\sigma$ is the scale parameter.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import genextreme

# Define different parameter settings (shape, location, scale)
params = [
    (-0.5, 80, 2),  # shape, location, scale
    (0.0, 85, 1),
    (0.0, 85, 2),
    (-0.1, 90, 2),
    (0.1, 80, 2)
]

# Generate x values (range of values where we want to evaluate the PDF)
x = np.linspace(70, 100, 1000)

# Set up the plot
plt.figure(figsize=(8, 4), dpi=300)

# Loop through each parameter setting and plot the corresponding GEV distribution
for param in params:
    shape, loc, scale = param
    # Generate the probability density function (PDF) for the GEV distribution
    cdf = genextreme.cdf(x, shape, loc, scale)
    plt.plot(x, cdf, label=f'shape={shape}, loc={loc}, scale={scale}')

# Add titles and labels
# plt.yticks([0.0, 0.1, 0.2, 0.3])
plt.title('GEV Distributions with Different Parameters')
plt.xlabel('Variable (Unit)')
plt.ylabel('Cumulative Distribution Function')
plt.legend()

plt.grid(ls='--')
plt.show()

# %% [markdown]
# # Generalized Extreme Value (GEV) Distribution Probability Density Function (PDF)
#
# The probability density function (PDF) of the Generalized Extreme Value (GEV) distribution is given by:
#
# $$
# f(x | \xi, \mu, \sigma) = \frac{1}{\sigma} \left( 1 + \xi \frac{x - \mu}{\sigma} \right)^{-(1/\xi + 1)} \exp \left( - \left( 1 + \xi \frac{x - \mu}{\sigma} \right)^{-1/\xi} \right)
# $$
#
# Where:
# - $\xi$ is the shape parameter,
# - $\mu$ is the location parameter,
# - $\sigma$ is the scale parameter.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import genextreme

# Define different parameter settings (shape, location, scale)
params = [
    (-0.5, 80, 2),  # shape, location, scale
    (0.0, 85, 1),
    (0.0, 85, 2),
    (-0.1, 90, 2),
    (0.1, 80, 2)
]

# Generate x values (range of values where we want to evaluate the PDF)
x = np.linspace(70, 100, 1000)

# Set up the plot
plt.figure(figsize=(8, 4), dpi=300)

# Loop through each parameter setting and plot the corresponding GEV distribution
for param in params:
    shape, loc, scale = param
    # Generate the probability density function (PDF) for the GEV distribution
    pdf = genextreme.pdf(x, shape, loc, scale)
    plt.plot(x, pdf, label=f'shape={shape}, loc={loc}, scale={scale}')

# Add titles and labels
# plt.yticks([0.0, 0.1, 0.2, 0.3])
plt.title('GEV Distributions with Different Parameters')
plt.xlabel('Variable (Unit)')
plt.ylabel('Cumulative Distribution Function')
plt.legend()

plt.grid(ls='--')
plt.show()
